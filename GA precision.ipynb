# %%
from matplotlib import pyplot as plt
import numpy as np
import time


from GA import GeneticAlgorithm

# %%
iterations = [10, 25, 50, 100, 250]

# %%
def obj_function(genome):
    x1, x2, x3, x4, x5, x6 = genome
    
    if x5==x6:
        x6=0
    if x4==x5 or x4==x6:
        x5 = x6 = 0
    if x4>x5 and x4>x6:
        x5 = x6 = 0
    if x5>x6 and x5>x4:
        x4 = x6 = 0
    if x6>x4 and x6>x5:
        x4 = x5 = 0
        
    if x3==0:
        return 0
    else:
        return x1 + (10-(x2/x3)) + (x4*9) + (x5*5) + (x6*1)

# %%
bestFitArray = []; gaExeArray = [];
for i in range(iterations[0]):
    ga_start = time.time()
    ga = GeneticAlgorithm(
        obj_function, 
        pop_size=100, 
        genome_length=6,
        lb=[0, 1, 1, 0, 0, 0 ],
        ub=[35, 8, 9, 1, 1, 1],
        timeplotbool = False
    )
    ga.generate_binary_population()
    ga.number_of_pairs = 4
    ga.selective_pressure = 1.3
    ga.mutation_rate = 0.1
    ga.run(25)
    best_genome, best_fitness = ga.get_best_genome()
    gaExeArray.append( time.time() - ga_start )
    bestFitArray.append(best_fitness)

print("Average best fitness for ",iterations[0]," iterations: ", sum(bestFitArray)/(iterations[0]))
print("Average GA exe time for ",iterations[0]," iterations: ", sum(gaExeArray)/(iterations[0]))
# Out:
# Average best fitness for  10  iterations:  53.04837301587302
# Average GA exe time for  10  iterations:  0.025699496269226074

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
fig.set_size_inches(18, 10)
fig.suptitle(str(iterations[0])+" iterations")
ax1.set_title("Best fitness values")
ax1.plot(np.arange(iterations[0]), bestFitArray, linewidth=4.0, color="#FFC300", marker="o", mfc="#000000")

ax2.set_title("Execution time")
ax2.plot(np.arange(iterations[0]), gaExeArray, linewidth=4.0, color="#FA8072", marker="o", mfc="#000000")

fig.show()
# Out:
# C:\Users\Nikhil Venkat\anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.

# %%
bestFitArray = []; gaExeArray = [];
for i in range(iterations[1]):
    ga_start = time.time()
    ga = GeneticAlgorithm(
        obj_function, 
        pop_size=100, 
        genome_length=6,
        lb=[0, 1, 1, 0, 0, 0 ],
        ub=[35, 8, 9, 1, 1, 1],
        timeplotbool = False
    )
    ga.generate_binary_population()
    ga.number_of_pairs = 4
    ga.selective_pressure = 1.3
    ga.mutation_rate = 0.1
    ga.run(25)
    best_genome, best_fitness = ga.get_best_genome()
    gaExeArray.append( time.time() - ga_start )
    bestFitArray.append(best_fitness)

print("Average best fitness for ",iterations[1]," iterations: ", sum(bestFitArray)/(iterations[1]))
print("Average GA exe time for ",iterations[1]," iterations: ", sum(gaExeArray)/(iterations[1]))
# Out:
# Average best fitness for  25  iterations:  53.28426984126984
# Average GA exe time for  25  iterations:  0.027042150497436523

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
fig.set_size_inches(18, 10)
fig.suptitle(str(iterations[1])+" iterations")
ax1.set_title("Best fitness values")
ax1.plot(np.arange(iterations[1]), bestFitArray, linewidth=4.0, color="#FFC300", marker="o", mfc="#000000")

ax2.set_title("Execution time")
ax2.plot(np.arange(iterations[1]), gaExeArray, linewidth=4.0, color="#FA8072", marker="o", mfc="#000000")

fig.show()
# Out:
# C:\Users\Nikhil Venkat\anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.

# %%
bestFitArray = []; gaExeArray = [];
for i in range(iterations[2]):
    ga_start = time.time()
    ga = GeneticAlgorithm(
        obj_function, 
        pop_size=100, 
        genome_length=6,
        lb=[0, 1, 1, 0, 0, 0 ],
        ub=[35, 8, 9, 1, 1, 1],
        timeplotbool = False
    )
    ga.generate_binary_population()
    ga.number_of_pairs = 4
    ga.selective_pressure = 1.3
    ga.mutation_rate = 0.1
    ga.run(25)
    best_genome, best_fitness = ga.get_best_genome()
    gaExeArray.append( time.time() - ga_start )
    bestFitArray.append(best_fitness)

print("Average best fitness for ",iterations[2]," iterations: ", sum(bestFitArray)/(iterations[2]))
print("Average GA exe time for ",iterations[2]," iterations: ", sum(gaExeArray)/(iterations[2]))
# Out:
# Average best fitness for  50  iterations:  53.36547619047619
# Average GA exe time for  50  iterations:  0.030799150466918945

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
fig.set_size_inches(18, 10)
fig.suptitle(str(iterations[2])+" iterations")
ax1.set_title("Best fitness values")
ax1.plot(np.arange(iterations[2]), bestFitArray, linewidth=4.0, color="#FFC300", marker="o", mfc="#000000")

ax2.set_title("Execution time")
ax2.plot(np.arange(iterations[2]), gaExeArray, linewidth=4.0, color="#FA8072", marker="o", mfc="#000000")

fig.show()
# Out:
# C:\Users\Nikhil Venkat\anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.

# %%
bestFitArray = []; gaExeArray = [];
for i in range(iterations[3]):
    ga_start = time.time()
    ga = GeneticAlgorithm(
        obj_function, 
        pop_size=100, 
        genome_length=6,
        lb=[0, 1, 1, 0, 0, 0 ],
        ub=[35, 8, 9, 1, 1, 1],
        timeplotbool = False
    )
    ga.generate_binary_population()
    ga.number_of_pairs = 4
    ga.selective_pressure = 1.3
    ga.mutation_rate = 0.1
    ga.run(25)
    best_genome, best_fitness = ga.get_best_genome()
    gaExeArray.append( time.time() - ga_start )
    bestFitArray.append(best_fitness)

print("Average best fitness for ",iterations[3]," iterations: ", sum(bestFitArray)/(iterations[3]))
print("Average GA exe time for ",iterations[3]," iterations: ", sum(gaExeArray)/(iterations[3]))
# Out:
# Average best fitness for  100  iterations:  53.34413888888889
# Average GA exe time for  100  iterations:  0.030530526638031005

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
fig.set_size_inches(18, 10)
fig.suptitle(str(iterations[3])+" iterations")
ax1.set_title("Best fitness values")
ax1.plot(np.arange(iterations[3]), bestFitArray, linewidth=4.0, color="#FFC300", marker="o", mfc="#000000")

ax2.set_title("Execution time")
ax2.plot(np.arange(iterations[3]), gaExeArray, linewidth=4.0, color="#FA8072", marker="o", mfc="#000000")

fig.show()
# Out:
# C:\Users\Nikhil Venkat\anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.

# %%
bestFitArray = []; gaExeArray = [];
for i in range(iterations[4]):
    ga_start = time.time()
    ga = GeneticAlgorithm(
        obj_function, 
        pop_size=100, 
        genome_length=6,
        lb=[0, 1, 1, 0, 0, 0 ],
        ub=[35, 8, 9, 1, 1, 1],
        timeplotbool = False
    )
    ga.generate_binary_population()
    ga.number_of_pairs = 4
    ga.selective_pressure = 1.3
    ga.mutation_rate = 0.1
    ga.run(25)
    best_genome, best_fitness = ga.get_best_genome()
    gaExeArray.append( time.time() - ga_start )
    bestFitArray.append(best_fitness)

print("Average best fitness for ",iterations[4]," iterations: ", sum(bestFitArray)/(iterations[4]))
print("Average GA exe time for ",iterations[4]," iterations: ", sum(gaExeArray)/(iterations[4]))
# Out:
# Average best fitness for  250  iterations:  53.34078571428571
# Average GA exe time for  250  iterations:  0.03050417423248291

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
fig.set_size_inches(18, 10)
fig.suptitle(str(iterations[4])+" iterations")
ax1.set_title("Best fitness values")
ax1.plot(np.arange(iterations[4]), bestFitArray, linewidth=4.0, color="#FFC300", marker="o", mfc="#000000")

ax2.set_title("Execution time")
ax2.plot(np.arange(iterations[4]), gaExeArray, linewidth=4.0, color="#FA8072", marker="o", mfc="#000000")

fig.show()
# Out:
# C:\Users\Nikhil Venkat\anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.
