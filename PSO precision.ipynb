# %%
from matplotlib import pyplot as plt
import numpy as np
import time

from PSO1 import PSO

# %%
iterations = [10, 25, 50, 100, 200, 300]

# %% [markdown]
# # Weightage calculator

# %%
def obj_function(genome):
    x1, x2, x3, x4, x5, x6 = genome
    
    if x5==x6:
        x6=0
    if x4==x5 or x4==x6:
        x5 = x6 = 0
    if x4>x5 and x4>x6:
        x5 = x6 = 0
    if x5>x6 and x5>x4:
        x4 = x6 = 0
    if x6>x4 and x6>x5:
        x4 = x5 = 0
        
    if x3==0:
        return 0
    else:
        return x1 + (10-(x2/x3)) + (x4*9) + (x5*5) + (x6*1)

# %% [markdown]
# # Average PSO

# %%
gBestArray = []; psoExeArray = [];
for i in range(iterations[0]):
    pso_start = time.time()
    instance = PSO(
        func=obj_function,
        dim=6,
        lb=[0, 1, 1, 0, 0, 0 ],
        ub=[35, 8, 9, 1, 1, 1],
        w=0.6, c1=0.7, c2=0.7,
        timeplotbool = False
    )

    pso_result = instance.run(max_iter=25)

    psoExeArray.append(time.time()-pso_start)
    gBestArray.append(pso_result.gbest_y)

print("Average PSO gBest for ",iterations[0]," iterations: ", sum(gBestArray)/(iterations[0]))
print("Average PSO exe time for ",iterations[0]," iterations: ", sum(psoExeArray)/(iterations[0]))
# Out:
# Average PSO gBest for  10  iterations:  53.48986031280149
# Average PSO exe time for  10  iterations:  0.007999992370605469

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
fig.set_size_inches(18, 10)
fig.suptitle(str(iterations[0])+" iterations")
ax1.set_title("gBest values")
ax1.plot(np.arange(iterations[0]), gBestArray, linewidth=4.0, color="#FFC300", marker="o", mfc="#000000")

ax2.set_title("Execution time")
ax2.plot(np.arange(iterations[0]), psoExeArray, linewidth=4.0, color="#FA8072", marker="o", mfc="#000000")

fig.show()
# Out:
# C:\Users\Nikhil Venkat\anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.

# %%
gBestArray = []; psoExeArray = [];
for i in range(iterations[1]):
    pso_start = time.time()
    instance = PSO(
        func=obj_function,
        dim=6,
        lb=[0, 1, 1, 0, 0, 0 ],
        ub=[35, 8, 9, 1, 1, 1],
        w=0.6, c1=0.7, c2=0.7,
        timeplotbool = False
    )

    pso_result = instance.run(max_iter=25)

    psoExeArray.append(time.time()-pso_start)
    gBestArray.append(pso_result.gbest_y)

print("Average PSO gBest for ",iterations[1]," iterations: ", sum(gBestArray)/(iterations[1]))
print("Average PSO exe time for ",iterations[1]," iterations: ", sum(psoExeArray)/(iterations[1]))
# Out:
# Average PSO gBest for  25  iterations:  53.513726648898846
# Average PSO exe time for  25  iterations:  0.009319839477539062

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
fig.set_size_inches(18, 10)
fig.suptitle(str(iterations[1])+" iterations")
ax1.set_title("gBest values")
ax1.plot(np.arange(iterations[1]), gBestArray, linewidth=4.0, color="#FFC300", marker="o", mfc="#000000")

ax2.set_title("Execution time")
ax2.plot(np.arange(iterations[1]), psoExeArray, linewidth=4.0, color="#FA8072", marker="o", mfc="#000000")

fig.show()
# Out:
# C:\Users\Nikhil Venkat\anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.

# %%
gBestArray = []; psoExeArray = [];
for i in range(iterations[2]):
    pso_start = time.time()
    instance = PSO(
        func=obj_function,
        dim=6,
        lb=[0, 1, 1, 0, 0, 0 ],
        ub=[35, 8, 9, 1, 1, 1],
        w=0.6, c1=0.7, c2=0.7,
        timeplotbool = False
    )

    pso_result = instance.run(max_iter=25)

    psoExeArray.append(time.time()-pso_start)
    gBestArray.append(pso_result.gbest_y)

print("Average PSO gBest for ",iterations[2]," iterations: ", sum(gBestArray)/(iterations[2]))
print("Average PSO exe time for ",iterations[2]," iterations: ", sum(psoExeArray)/(iterations[2]))
# Out:
# Average PSO gBest for  50  iterations:  53.55155215140499
# Average PSO exe time for  50  iterations:  0.009380059242248535

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
fig.set_size_inches(18, 10)
fig.suptitle(str(iterations[2])+" iterations")
ax1.set_title("gBest values")
ax1.plot(np.arange(iterations[2]), gBestArray, linewidth=4.0, color="#FFC300", marker="o", mfc="#000000")

ax2.set_title("Execution time")
ax2.plot(np.arange(iterations[2]), psoExeArray, linewidth=4.0, color="#FA8072", marker="o", mfc="#000000")

fig.show()
# Out:
# C:\Users\Nikhil Venkat\anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.

# %%
gBestArray = []; psoExeArray = [];
for i in range(iterations[3]):
    pso_start = time.time()
    instance = PSO(
        func=obj_function,
        dim=6,
        lb=[0, 1, 1, 0, 0, 0 ],
        ub=[35, 8, 9, 1, 1, 1],
        w=0.6, c1=0.7, c2=0.7,
        timeplotbool = False
    )

    pso_result = instance.run(max_iter=25)

    psoExeArray.append(time.time()-pso_start)
    gBestArray.append(pso_result.gbest_y)

print("Average PSO gBest for ",iterations[3]," iterations: ", sum(gBestArray)/(iterations[3]))
print("Average PSO exe time for ",iterations[3]," iterations: ", sum(psoExeArray)/(iterations[3]))
# Out:
# Average PSO gBest for  100  iterations:  53.52056151405087
# Average PSO exe time for  100  iterations:  0.009300034046173095

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
fig.set_size_inches(18, 10)
fig.suptitle(str(iterations[3])+" iterations")
ax1.set_title("gBest values")
ax1.plot(np.arange(iterations[3]), gBestArray, linewidth=4.0, color="#FFC300", marker="o", mfc="#000000")

ax2.set_title("Execution time")
ax2.plot(np.arange(iterations[3]), psoExeArray, linewidth=4.0, color="#FA8072", marker="o", mfc="#000000")

fig.show()
# Out:
# C:\Users\Nikhil Venkat\anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.

# %%
gBestArray = []; psoExeArray = [];
for i in range(iterations[4]):
    pso_start = time.time()
    instance = PSO(
        func=obj_function,
        dim=6,
        lb=[0, 1, 1, 0, 0, 0 ],
        ub=[35, 8, 9, 1, 1, 1],
        w=0.6, c1=0.7, c2=0.7,
        timeplotbool = False
    )

    pso_result = instance.run(max_iter=25)

    psoExeArray.append(time.time()-pso_start)
    gBestArray.append(pso_result.gbest_y)

print("Average PSO gBest for ",iterations[4]," iterations: ", sum(gBestArray)/(iterations[4]))
print("Average PSO exe time for ",iterations[4]," iterations: ", sum(psoExeArray)/(iterations[4]))
# Out:
# Average PSO gBest for  200  iterations:  53.534205876832765
# Average PSO exe time for  200  iterations:  0.009370254278182983

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
fig.set_size_inches(18, 10)
fig.suptitle(str(iterations[4])+" iterations")
ax1.set_title("gBest values")
ax1.plot(np.arange(iterations[4]), gBestArray, linewidth=4.0, color="#FFC300", marker="o", mfc="#000000")

ax2.set_title("Execution time")
ax2.plot(np.arange(iterations[4]), psoExeArray, linewidth=4.0, color="#FA8072", marker="o", mfc="#000000")

fig.show()
# Out:
# C:\Users\Nikhil Venkat\anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.
